# %%
from sagemaker.core import ScriptProcessor, image_uris
base_job_prefix = "debug-1"

sklearn_processor = ScriptProcessor(
    image_uri=image_uris.retrieve(
        framework="sklearn",
        region="us-east-1",
        version="1.2-1",
        py_version="py3",
        instance_type="ml.m5.xlarge",
    ),
    instance_type="ml.m5.xlarge",
    instance_count=1,
    base_job_name=f"{base_job_prefix}-sklearn-preprocess-job-tags",
    tags= [{'Key': 'project', 'Value': 'tags-testing'}],
    role= "arn:aws:iam::211125564141:role/Admin"
)
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/nargokul/.pyenv/versions/3.10.13/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/nargokul/.pyenv/versions/3.10.13/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/nargokul/.pyenv/versions/3.10.13/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/Users/nargokul/.pyenv/versions/3.10.13/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/Users/nargokul/.pyenv/versions/3.10.13/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/vx/jl46pbwx02q9fjkt411r2nz80000gr/T/ipykernel_65663/1919898306.py", line 1, in <module>
#     from sagemaker.core import ScriptProcessor, image_uris
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/sagemaker-core/src/sagemaker/core/__init__.py", line 8, in <module>
#     from sagemaker.core.processing import (  # noqa: F401
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/sagemaker-core/src/sagemaker/core/processing.py", line 55, in <module>
#     from sagemaker.core.resources import ProcessingJob
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/sagemaker-core/src/sagemaker/core/resources.py", line 46, in <module>
#     from sagemaker.core.serializers.base import BaseSerializer
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/sagemaker-core/src/sagemaker/core/serializers/__init__.py", line 6, in <module>
#     from sagemaker.core.serializers.base import *  # noqa: F401, F403
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/sagemaker-core/src/sagemaker/core/serializers/base.py", line 22, in <module>
#     from pandas import DataFrame
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/pandas/__init__.py", line 26, in <module>
#     from pandas.compat import (
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/pandas/compat/__init__.py", line 29, in <module>
#     from pandas.compat.pyarrow import (
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/pandas/compat/pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/nargokul/.pyenv/versions/3.10.13/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/nargokul/.pyenv/versions/3.10.13/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/nargokul/.pyenv/versions/3.10.13/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/Users/nargokul/.pyenv/versions/3.10.13/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/Users/nargokul/.pyenv/versions/3.10.13/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/vx/jl46pbwx02q9fjkt411r2nz80000gr/T/ipykernel_65663/1919898306.py", line 1, in <module>
#     from sagemaker.core import ScriptProcessor, image_uris
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/sagemaker-core/src/sagemaker/core/__init__.py", line 8, in <module>
#     from sagemaker.core.processing import (  # noqa: F401
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/sagemaker-core/src/sagemaker/core/processing.py", line 55, in <module>
#     from sagemaker.core.resources import ProcessingJob
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/sagemaker-core/src/sagemaker/core/resources.py", line 46, in <module>
#     from sagemaker.core.serializers.base import BaseSerializer
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/sagemaker-core/src/sagemaker/core/serializers/__init__.py", line 6, in <module>
#     from sagemaker.core.serializers.base import *  # noqa: F401, F403
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/sagemaker-core/src/sagemaker/core/serializers/base.py", line 22, in <module>
#     from pandas import DataFrame
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/pandas/core/api.py", line 9, in <module>
#     from pandas.core.dtypes.dtypes import (
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/pandas/core/dtypes/dtypes.py", line 24, in <module>
#     from pandas._libs import (
#   File "/Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# AttributeError: _ARRAY_API not found
# [01/06/26 11:03:59] INFO     Found credentials in shared credentials file: ~/.aws/credentials   ]8;id=873625;file:///Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=411522;file:///Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/botocore/credentials.py#1392\1392]8;;\
# sagemaker.config INFO - Not applying SDK defaults from location: /Library/Application Support/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /Users/nargokul/Library/Application Support/sagemaker/config.yaml
# [01/06/26 11:04:00] INFO     Found credentials in shared credentials file: ~/.aws/credentials   ]8;id=302222;file:///Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=801428;file:///Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/botocore/credentials.py#1392\1392]8;;\

# %%
sklearn_processor.run(
    code="test_script.py"
)
# Out:
# [01/06/26 11:04:07] INFO     Creating processing-job with name                                    ]8;id=41315;file:///Users/nargokul/workspace/sagemaker-python-sdk/sagemaker-core/src/sagemaker/core/processing.py\processing.py]8;;\:]8;id=629262;file:///Users/nargokul/workspace/sagemaker-python-sdk/sagemaker-core/src/sagemaker/core/processing.py#609\609]8;;\
#                              debug-1-sklearn-preprocess-job-tags-2026-01-06-19-04-05-641
# [01/06/26 11:04:08] INFO     Found credentials in shared credentials file: ~/.aws/credentials   ]8;id=26615;file:///Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=424189;file:///Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/botocore/credentials.py#1392\1392]8;;\
# /Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/rich/live.py:231: UserWarning:
# install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
#                     WARNING  No region provided. Using default region.                                 ]8;id=555642;file:///Users/nargokul/workspace/sagemaker-python-sdk/sagemaker-core/src/sagemaker/core/utils/utils.py\utils.py]8;;\:]8;id=421982;file:///Users/nargokul/workspace/sagemaker-python-sdk/sagemaker-core/src/sagemaker/core/utils/utils.py#340\340]8;;\
#                     INFO     Runs on sagemaker prod, region:us-east-1                                  ]8;id=547290;file:///Users/nargokul/workspace/sagemaker-python-sdk/sagemaker-core/src/sagemaker/core/utils/utils.py\utils.py]8;;\:]8;id=357923;file:///Users/nargokul/workspace/sagemaker-python-sdk/sagemaker-core/src/sagemaker/core/utils/utils.py#354\354]8;;\
#                     INFO     Found credentials in shared credentials file: ~/.aws/credentials   ]8;id=450725;file:///Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=925751;file:///Users/nargokul/workspace/sagemaker-python-sdk/venv10/lib/python3.10/site-packages/botocore/credentials.py#1392\1392]8;;\
# [01/06/26 11:06:36] INFO     debug-1-sklearn-preprocess-job-tags-2026-01-06-19-04-05-641/algo-1- ]8;id=572549;file:///Users/nargokul/workspace/sagemaker-python-sdk/sagemaker-core/src/sagemaker/core/resources.py\resources.py]8;;\:]8;id=97857;file:///Users/nargokul/workspace/sagemaker-python-sdk/sagemaker-core/src/sagemaker/core/resources.py#32152\32152]8;;\
#                              1767726309:
#                              Hello from processing script!
# [01/06/26 11:07:02] INFO     Final Resource Status: Completed                                    ]8;id=387035;file:///Users/nargokul/workspace/sagemaker-python-sdk/sagemaker-core/src/sagemaker/core/resources.py\resources.py]8;;\:]8;id=136009;file:///Users/nargokul/workspace/sagemaker-python-sdk/sagemaker-core/src/sagemaker/core/resources.py#32155\32155]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
